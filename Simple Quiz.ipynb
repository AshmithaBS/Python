# %%
from tkinter import*

def clicked():
    global score
    score=0
    if selected1.get()==1:
        score+=1
    if selected2.get()==3:
        score+=1
    if selected3.get()==2:
        score+=1
    if selected4.get()==4:
        score+=1
    
    if score>=0:
        result.delete(0,END)
        result.insert(0,score)

    
window=Tk()
window.title("QUIZ")
window.geometry("500x600")


  
    
    

selected1=IntVar()  

qstn_1=Label(window,text="1.What name has ISRO given to the rover sent with the Chandrayaan-3 mission?")
qstn_1.place(x=5,y=20)

rad11=Radiobutton(window,text="Pragyan",value=1,variable=selected1,command=lambda:clicked(1))
rad12=Radiobutton(window,text="Gyan Ganga",value=2,variable=selected1,command=lambda:clicked(2))
rad13=Radiobutton(window,text="Vikram",value=3,variable=selected1,command=lambda:clicked(3))
rad14=Radiobutton(window,text="None of the above",value=4,variable=selected1,command=lambda:clicked(4))

rad11.place(x=5,y=40)
rad12.place(x=5,y=60)
rad13.place(x=5,y=80)
rad14.place(x=5,y=100)

selected2=IntVar()  

qstn_2=Label(window,text="2.What is Bryology?")
qstn_2.place(x=5,y=140)

rad21=Radiobutton(window,text="Study of food",value=1,variable=selected2,command=lambda:clicked(1))
rad22=Radiobutton(window,text="Study of fruit",value=2,variable=selected2,command=lambda:clicked(2))
rad23=Radiobutton(window,text="Study of mosses and liver worts",value=3,variable=selected2,command=lambda:clicked(3))
rad24=Radiobutton(window,text="Study of embryo",value=4,variable=selected2,command=lambda:clicked(4))

rad21.place(x=5,y=160)
rad22.place(x=5,y=180)
rad23.place(x=5,y=200)
rad24.place(x=5,y=220)

selected3=IntVar()  

qstn_3=Label(window,text="3.Who among the following is the invention of J. C. Bose?")
qstn_3.place(x=5,y=260)


rad31=Radiobutton(window,text="Electron",value=1,variable=selected3,command=lambda:clicked(1))
rad32=Radiobutton(window,text="Wavelength theory of light",value=2,variable=selected3,command=lambda:clicked(2))
rad33=Radiobutton(window,text="Cosmic radiation",value=3,variable=selected3,command=lambda:clicked(3))
rad34=Radiobutton(window,text="Ultra short radio waves",value=4,variable=selected3,command=lambda:clicked(4))

rad31.place(x=5,y=280)
rad32.place(x=5,y=300)
rad33.place(x=5,y=320)
rad34.place(x=5,y=340)

selected4=IntVar()  

qstn_4=Label(window,text="3.Who among the following is the invention of J. C. Bose?")
qstn_4.place(x=5,y=400)


rad41=Radiobutton(window,text="Electron",value=1,variable=selected4,command=lambda:clicked(1))
rad42=Radiobutton(window,text="Wavelength theory of light",value=2,variable=selected4,command=lambda:clicked(2))
rad43=Radiobutton(window,text="Cosmic radiation",value=3,variable=selected4,command=lambda:clicked(3))
rad44=Radiobutton(window,text="Ultra short radio waves",value=4,variable=selected4,command=lambda:clicked(4))

rad41.place(x=5,y=420)
rad42.place(x=5,y=440)
rad43.place(x=5,y=460)
rad44.place(x=5,y=480)

submit_butn=Button(window,text="submit",width=10,bg="light blue",command=clicked)
submit_butn.place(x=20,y=520)


result=Entry(window)
result.place(x=20,y=550)


window.mainloop()
